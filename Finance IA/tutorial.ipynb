# %%
import investment_appraisal as ia

# %%
from investment_appraisal import npv

# %%
cashflows = [-100000, 70000, 85000, 65000]
rate = 0.12

# %%
npv_value = npv(0.12, cashflows)
print(npv_value)
# Out:
# 76527.19569970842

# %%
from investment_appraisal import irr

# %%
irr_value = irr(cashflows)
print(irr_value)
# Out:
# 0.5318704898373177

# %%
pb = ia.payback_period(cashflows)
dpb = ia.discounted_payback(rate, cashflows)

print(pb)
print(dpb)
# Out:
# 1.3529411764705883
# 1.5534117647058825

# %%
rate_A = 0.05
initial_cost_A = 100000
n = 5
maintenance_A = 4000

# %%
eac_A = ia.eac(rate_A, n, initial_cost_A, maintenance_A)

# %%
print(eac_A)
# Out:
# 27097.479812826798
